# %% [markdown]
# <a href="https://colab.research.google.com/github/kaisei3506/close_price_prediction/blob/main/past60days_future1day_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install japanize_matplotlib
import japanize_matplotlib
# Out:
# Requirement already satisfied: japanize_matplotlib in /usr/local/lib/python3.11/dist-packages (1.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)

# %%
# 再現性の確保

import os
import random
import numpy as np
import tensorflow as tf

os.environ['PYTHONHASHSEED'] = '42'

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

try:
    tf.config.experimental.enable_op_determinism()
    print("TensorFlow deterministic operations enabled.")
except AttributeError as e:
    print(f"Note: tf.config.experimental.enable_op_determinism() not available in this TF version. Using TF_DETERMINISTIC_OPS='1' might be necessary if supported. Error: {e}")
# Out:
# TensorFlow deterministic operations enabled.

# %%
df = pd.read_csv('/content/drive/MyDrive/assignment-main(new)/Trainee/time-series-prediction/my_cleaned_stock_price.csv')
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')
df
# Out:
#             close   open   high    low        volume  return
# date
# 1987-02-12  182.4  182.4  182.4  182.4  1.280000e+09  0.1625
# 1987-02-13  172.5  176.5  176.5  172.5  4.223800e+08 -0.0543
# 1987-02-16  175.5  166.7  175.5  165.7  3.605100e+08  0.0174
# 1987-02-17  182.4  176.5  184.3  175.5  8.815100e+08  0.0393
# 1987-02-18  191.2  186.3  191.2  186.3  7.950900e+08  0.0482
# ...           ...    ...    ...    ...           ...     ...
# 2024-07-26  157.9  159.3  159.6  157.9  1.550800e+08 -0.0013
# 2024-07-29  159.7  158.7  160.2  158.4  1.262800e+08  0.0114
# 2024-07-30  158.7  158.8  159.2  158.0  1.381400e+08 -0.0063
# 2024-07-31  160.4  158.2  160.7  158.1  1.739100e+08  0.0107
# 2024-08-01  156.3  159.3  159.4  156.1  7.915000e+07 -0.0256
#
# [9202 rows x 6 columns]

# %%
import holidays

def compute_rsi(data, window=14):
    delta = data['close'].diff()
    gain = (delta.where(delta > 0, 0)).ewm(span=window, adjust=False).mean()
    loss = (-delta.where(delta < 0, 0)).ewm(span=window, adjust=False).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

def engineer(df_old):

  df_new = df_old.copy()

  df_new['sin_dayofyear'] = np.sin(2 * np.pi * df_new.index.dayofyear / 365)
  df_new['cos_dayofyear'] = np.cos(2 * np.pi * df_new.index.dayofyear / 365)
  df_new['sin_dayofmonth'] = np.sin(2 * np.pi * df_new.index.day / 30)
  df_new['cos_dayofmonth'] = np.cos(2 * np.pi * df_new.index.day / 30)
  df_new['sin_dayofweek'] = np.sin(2 * np.pi * df_new.index.dayofweek / 7)
  df_new['cos_dayofweek'] = np.cos(2 * np.pi * df_new.index.dayofweek / 7)
  '''
  # 日本の休日
  jp_holidays = holidays.Japan()
  df_new['holiday'] = df_new.index.map(lambda x: 1 if x in jp_holidays else 0)

  # 移動平均、相対力指数
  sma_list = [5, 10, 20]
  for i in sma_list:
    df_new[f'sma_{i}'] = df_new['close'].rolling(window=i).mean()
    df_new[f'ema_{i}'] = df_new['close'].ewm(span=i, adjust=False).mean()
    df_new[f'rsi_{i}'] = compute_rsi(df_new, window=i)

  # 標準偏差
  for i in sma_list:
    df_new[f'std_{i}'] = df_new['close'].rolling(window=i).std()

  # 急激な上昇をとらえる
  for i in range(len(sma_list)):
    for j in range(i+1, len(sma_list)):

      df_new[f'sma_{sma_list[i]}vs{sma_list[j]}'] = df_new[f'sma_{sma_list[i]}'] / df_new[f'sma_{sma_list[j]}']

      # ゴールデンクロス
      df_new[f'gc_{sma_list[i]}vs{sma_list[j]}'] = (df_new[f'sma_{sma_list[i]}'].shift(1) < df_new[f'sma_{sma_list[j]}'].shift(1)) & (df_new[f'sma_{sma_list[i]}'] >= df_new[f'sma_{sma_list[j]}'])
      # デッドクロス
      df_new[f'dc_{sma_list[i]}vs{sma_list[j]}'] = (df_new[f'sma_{sma_list[i]}'].shift(1) > df_new[f'sma_{sma_list[j]}'].shift(1)) & (df_new[f'sma_{sma_list[i]}'] <= df_new[f'sma_{sma_list[j]}'])

      # MACD
      df_new[f'macd_{sma_list[i]}vs{sma_list[j]}'] = df_new[f'ema_{sma_list[i]}'] - df_new[f'ema_{sma_list[j]}']
      df_new[f'macd_signal_{sma_list[i]}vs{sma_list[j]}'] = df_new[f'macd_{sma_list[i]}vs{sma_list[j]}'].ewm(span=9, adjust=False).mean()

  # ADX
  epsilon = 1e-6
  df_new['+DM'] = df_new['high'] - df_new['high'].shift(1)
  df_new['-DM'] = df_new['low'].shift(1) - df_new['low']
  df_new['TR'] = np.maximum.reduce([
    df_new['high'] - df_new['low'],
    abs(df_new['high'] - df_new['close'].shift(1)),
    abs(df_new['low'] - df_new['close'].shift(1))
    ])
  df_new['+DI'] = df_new['+DM'].rolling(window=14).sum() / (df_new['TR'].rolling(window=14).sum() + epsilon) * 100
  df_new['-DI'] = df_new['-DM'].rolling(window=14).sum() / (df_new['TR'].rolling(window=14).sum() + epsilon) * 100
  df_new['DX'] = abs((df_new['+DI'] - df_new['-DI']) / (df_new['+DI'] + df_new['-DI'] + epsilon)) * 100
  df_new['ADX'] = df_new['DX'].rolling(window=14).mean()

  # ストキャスティクス
  df_new['%K'] = (df_new['close'] - df_new['low'].rolling(window=14).min()) / (df_new['high'].rolling(window=14).max() - df_new['low'].rolling(window=14).min()) * 100
  df_new['%D'] = df_new['%K'].rolling(window=3).mean()
  '''


  #df_new = df_new.drop(['open', 'high', 'low'], axis=1)

  df_new = df_new.dropna()


  return df_new

engineered_df = engineer(df)
engineered_df
# Out:
#             close   open   high    low        volume  return  sin_dayofyear  \
# date
# 1987-02-12  182.4  182.4  182.4  182.4  1.280000e+09  0.1625       0.674444
# 1987-02-13  172.5  176.5  176.5  172.5  4.223800e+08 -0.0543       0.687053
# 1987-02-16  175.5  166.7  175.5  165.7  3.605100e+08  0.0174       0.723644
# 1987-02-17  182.4  176.5  184.3  175.5  8.815100e+08  0.0393       0.735417
# 1987-02-18  191.2  186.3  191.2  186.3  7.950900e+08  0.0482       0.746972
# ...           ...    ...    ...    ...           ...     ...            ...
# 2024-07-26  157.9  159.3  159.6  157.9  1.550800e+08 -0.0013      -0.425000
# 2024-07-29  159.7  158.7  160.2  158.4  1.262800e+08  0.0114      -0.471160
# 2024-07-30  158.7  158.8  159.2  158.0  1.381400e+08 -0.0063      -0.486273
# 2024-07-31  160.4  158.2  160.7  158.1  1.739100e+08  0.0107      -0.501242
# 2024-08-01  156.3  159.3  159.4  156.1  7.915000e+07 -0.0256      -0.516062
#
#             cos_dayofyear  sin_dayofmonth  cos_dayofmonth  sin_dayofweek  \
# date
# 1987-02-12       0.738326    5.877853e-01       -0.809017       0.433884
# 1987-02-13       0.726608    4.067366e-01       -0.913545      -0.433884
# 1987-02-16       0.690173   -2.079117e-01       -0.978148       0.000000
# 1987-02-17       0.677615   -4.067366e-01       -0.913545       0.781831
# 1987-02-18       0.664855   -5.877853e-01       -0.809017       0.974928
# ...                   ...             ...             ...            ...
# 2024-07-26      -0.905193   -7.431448e-01        0.669131      -0.433884
# 2024-07-29      -0.882048   -2.079117e-01        0.978148       0.000000
# 2024-07-30      -0.873807   -1.133108e-15        1.000000       0.781831
# 2024-07-31      -0.865307    2.079117e-01        0.978148       0.974928
# 2024-08-01      -0.856551    2.079117e-01        0.978148       0.433884
#
#             cos_dayofweek
# date
# 1987-02-12      -0.900969
# 1987-02-13      -0.900969
# 1987-02-16       1.000000
# 1987-02-17       0.623490
# 1987-02-18      -0.222521
# ...                   ...
# 2024-07-26      -0.900969
# 2024-07-29       1.000000
# 2024-07-30       0.623490
# 2024-07-31      -0.222521
# 2024-08-01      -0.900969
#
# [9202 rows x 12 columns]

# %%
train_valid = engineered_df['2019-01-01':'2023-12-31']

train = train_valid[:'2022-11-30']
enbargo_train_valid = train_valid['2022-12-01':'2022-12-31']
valid = train_valid['2023-01-01':'2023-07-31']
enbargo_valid_test = engineered_df['2023-08-01':'2024-12-31']
test = engineered_df['2024-01-01':'2024-07-31']

# %%
sequence_length = 22
predict_length = 1

def create_dataset(data, sequence_length, predict_length):
  X, y = [], []
  for i in range(len(data) - sequence_length - predict_length + 1):
    X.append(data[i:i+sequence_length, :])
    y.append(data[i+sequence_length:i+sequence_length+predict_length, 0])
  return np.array(X), np.array(y)

X_train, y_train = create_dataset(train.values, sequence_length, predict_length)
X_valid, y_valid = create_dataset(valid.values, sequence_length, predict_length)
X_test, y_test = create_dataset(test.values, sequence_length, predict_length)
y_train = y_train.reshape(y_train.shape[0], y_train.shape[1], 1)
y_valid = y_valid.reshape(y_valid.shape[0], y_valid.shape[1], 1)
print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (928, 22, 12)
# (928, 1, 1)
# (120, 22, 12)
# (120, 1, 1)

# %%
from sklearn.preprocessing import StandardScaler

# 特徴量（X）のスケーリング
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_valid_scaled = scaler_X.transform(X_valid.reshape(-1, X_valid.shape[-1])).reshape(X_valid.shape)
X_test_scaled = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# 目的変数（y）のスケーリング
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, y_train.shape[-1])).reshape(y_train.shape)
y_valid_scaled = scaler_y.transform(y_valid.reshape(-1, y_valid.shape[-1])).reshape(y_valid.shape)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers as optim
from tensorflow.keras import regularizers
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Layer
from tensorflow.keras.models import Model

# %%
# LSTM

lstm_model = Sequential()

lstm_model.add(LSTM(units=128,
                    return_sequences=True,
                    input_shape=(X_train.shape[1], X_train.shape[2]),
                    kernel_regularizer=regularizers.l2(0.001),
                    recurrent_regularizer=regularizers.l2(0.001)
                    )
)

lstm_model.add(Dropout(0.2))

lstm_model.add(LSTM(units=64,
                    return_sequences=False,
                    kernel_regularizer=regularizers.l2(0.001),
                    recurrent_regularizer=regularizers.l2(0.001)
                    )
)

lstm_model.add(Dropout(0.2))

lstm_model.add(Dense(predict_length,
                     kernel_regularizer=regularizers.l2(0.001)
                     )
)


optimizer = optim.Adam(learning_rate=0.001)
lstm_model.compile(optimizer=optimizer, loss='mse')
lstm_model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                  │ (None, 22, 128)        │        72,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 22, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 121,665 (475.25 KB)
#  Trainable params: 121,665 (475.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30, restore_best_weights=True)
lstm_model.fit(X_train_scaled, y_train_scaled,
               epochs=1000,
               batch_size=64,
               validation_data=(X_valid_scaled, y_valid_scaled),
               shuffle=False,
               callbacks=[es])

# 検証データの損失が最も小さかったエポックを取得
best_epoch = np.argmin(lstm_model.history.history['val_loss']) + 1
print(f"検証データの損失が最も小さかったエポック: {best_epoch}")
# そのエポックの学習損失と検証損失を取得
best_train_loss = lstm_model.history.history['loss'][best_epoch - 1]
best_val_loss = lstm_model.history.history['val_loss'][best_epoch - 1]
print(f"エポック {best_epoch}での学習損失: {best_train_loss}")
print(f"エポック {best_epoch}での検証損失: {best_val_loss}")
# Out:
# Epoch 1/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - loss: 0.8544 - val_loss: 0.4011
# Epoch 2/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - loss: 0.5441 - val_loss: 1.0349
# Epoch 3/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.6872 - val_loss: 2.5452
# Epoch 4/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - loss: 0.3845 - val_loss: 0.3997
# Epoch 5/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 282ms/step - loss: 0.3498 - val_loss: 0.3737
# Epoch 6/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - loss: 0.3303 - val_loss: 0.3699
# Epoch 7/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - loss: 0.3318 - val_loss: 0.6242
# Epoch 8/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - loss: 0.3170 - val_loss: 0.3191
# Epoch 9/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.2890 - val_loss: 0.5588
# Epoch 10/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.2776 - val_loss: 0.2939
# Epoch 11/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.2612 - val_loss: 0.3387
# Epoch 12/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.2506 - val_loss: 0.2979
# Epoch 13/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.2391 - val_loss: 0.2943
# Epoch 14/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.2308 - val_loss: 0.2743
# Epoch 15/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.2215 - val_loss: 0.2586
# Epoch 16/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.2136 - val_loss: 0.2571
# Epoch 17/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.2061 - val_loss: 0.2459
# Epoch 18/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.1992 - val_loss: 0.2328
# Epoch 19/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 0.1924 - val_loss: 0.2253
# Epoch 20/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.1846 - val_loss: 0.1983
# Epoch 21/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1805 - val_loss: 0.2032
# Epoch 22/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1768 - val_loss: 0.2022
# Epoch 23/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1761 - val_loss: 0.2641
# Epoch 24/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1807 - val_loss: 0.2001
# Epoch 25/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1971 - val_loss: 0.4940
# Epoch 26/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - loss: 0.1689 - val_loss: 0.1794
# Epoch 27/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.1628 - val_loss: 0.4756
# Epoch 28/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.1530 - val_loss: 0.1690
# Epoch 29/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1470 - val_loss: 0.3246
# Epoch 30/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1423 - val_loss: 0.1607
# Epoch 31/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1373 - val_loss: 0.2453
# Epoch 32/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1336 - val_loss: 0.1532
# Epoch 33/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - loss: 0.1288 - val_loss: 0.2052
# Epoch 34/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1264 - val_loss: 0.1520
# Epoch 35/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.1221 - val_loss: 0.1799
# Epoch 36/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.1202 - val_loss: 0.1410
# Epoch 37/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.1223 - val_loss: 0.2499
# Epoch 38/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1218 - val_loss: 0.1284
# Epoch 39/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1190 - val_loss: 0.2625
# Epoch 40/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1142 - val_loss: 0.1314
# Epoch 41/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1131 - val_loss: 0.2704
# Epoch 42/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.1094 - val_loss: 0.1176
# Epoch 43/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1064 - val_loss: 0.2446
# Epoch 44/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.1059 - val_loss: 0.1221
# Epoch 45/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1019 - val_loss: 0.2328
# Epoch 46/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 0.0989 - val_loss: 0.1173
# Epoch 47/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.0968 - val_loss: 0.1982
# Epoch 48/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0966 - val_loss: 0.1129
# Epoch 49/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 0.0946 - val_loss: 0.2181
# Epoch 50/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0949 - val_loss: 0.1046
# Epoch 51/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0924 - val_loss: 0.1863
# Epoch 52/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0900 - val_loss: 0.1135
# Epoch 53/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0891 - val_loss: 0.2044
# Epoch 54/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0901 - val_loss: 0.1025
# Epoch 55/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - loss: 0.0917 - val_loss: 0.2066
# Epoch 56/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 0.0885 - val_loss: 0.0945
# Epoch 57/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0867 - val_loss: 0.2511
# Epoch 58/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0847 - val_loss: 0.0997
# Epoch 59/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0811 - val_loss: 0.2269
# Epoch 60/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0795 - val_loss: 0.0926
# Epoch 61/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0762 - val_loss: 0.1786
# Epoch 62/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 0.0758 - val_loss: 0.0903
# Epoch 63/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0740 - val_loss: 0.1616
# Epoch 64/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - loss: 0.0723 - val_loss: 0.0912
# Epoch 65/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 0.0719 - val_loss: 0.1556
# Epoch 66/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0728 - val_loss: 0.0899
# Epoch 67/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0750 - val_loss: 0.1732
# Epoch 68/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0741 - val_loss: 0.0939
# Epoch 69/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0788 - val_loss: 0.2143
# Epoch 70/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0740 - val_loss: 0.0846
# Epoch 71/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 0.0723 - val_loss: 0.1828
# Epoch 72/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0695 - val_loss: 0.0861
# Epoch 73/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0663 - val_loss: 0.1900
# Epoch 74/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0647 - val_loss: 0.0778
# Epoch 75/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0612 - val_loss: 0.1186
# Epoch 76/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0605 - val_loss: 0.0822
# Epoch 77/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0626 - val_loss: 0.1368
# Epoch 78/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0633 - val_loss: 0.0764
# Epoch 79/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0685 - val_loss: 0.1740
# Epoch 80/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 0.0653 - val_loss: 0.0762
# Epoch 81/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.0660 - val_loss: 0.1743
# Epoch 82/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0615 - val_loss: 0.0740
# Epoch 83/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0643 - val_loss: 0.1801
# Epoch 84/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0595 - val_loss: 0.0696
# Epoch 85/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0586 - val_loss: 0.1726
# Epoch 86/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0571 - val_loss: 0.0709
# Epoch 87/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0552 - val_loss: 0.1404
# Epoch 88/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0538 - val_loss: 0.0753
# Epoch 89/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0532 - val_loss: 0.1242
# Epoch 90/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 0.0534 - val_loss: 0.0705
# Epoch 91/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0570 - val_loss: 0.1319
# Epoch 92/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 0.0566 - val_loss: 0.0738
# Epoch 93/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0613 - val_loss: 0.1679
# Epoch 94/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0563 - val_loss: 0.0706
# Epoch 95/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0586 - val_loss: 0.1878
# Epoch 96/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0565 - val_loss: 0.0711
# Epoch 97/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0591 - val_loss: 0.1994
# Epoch 98/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0548 - val_loss: 0.0722
# Epoch 99/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0546 - val_loss: 0.1572
# Epoch 100/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.0510 - val_loss: 0.0690
# Epoch 101/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 0.0534 - val_loss: 0.1896
# Epoch 102/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0534 - val_loss: 0.0621
# Epoch 103/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0528 - val_loss: 0.1671
# Epoch 104/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0477 - val_loss: 0.0617
# Epoch 105/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0505 - val_loss: 0.1810
# Epoch 106/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0485 - val_loss: 0.0623
# Epoch 107/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0464 - val_loss: 0.1636
# Epoch 108/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0457 - val_loss: 0.0654
# Epoch 109/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0464 - val_loss: 0.1570
# Epoch 110/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.0474 - val_loss: 0.0628
# Epoch 111/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0458 - val_loss: 0.1315
# Epoch 112/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0444 - val_loss: 0.0574
# Epoch 113/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0435 - val_loss: 0.0995
# Epoch 114/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0421 - val_loss: 0.0565
# Epoch 115/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0417 - val_loss: 0.0932
# Epoch 116/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0402 - val_loss: 0.0514
# Epoch 117/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0405 - val_loss: 0.0809
# Epoch 118/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0402 - val_loss: 0.0564
# Epoch 119/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0421 - val_loss: 0.0854
# Epoch 120/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 0.0398 - val_loss: 0.0522
# Epoch 121/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.0400 - val_loss: 0.0684
# Epoch 122/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0390 - val_loss: 0.0541
# Epoch 123/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0405 - val_loss: 0.0601
# Epoch 124/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0366 - val_loss: 0.0535
# Epoch 125/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0350 - val_loss: 0.0524
# Epoch 126/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0340 - val_loss: 0.0550
# Epoch 127/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0370 - val_loss: 0.0578
# Epoch 128/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0468 - val_loss: 0.0935
# Epoch 129/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0536 - val_loss: 0.0729
# Epoch 130/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - loss: 0.0831 - val_loss: 0.1161
# Epoch 131/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0500 - val_loss: 0.0668
# Epoch 132/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0843 - val_loss: 0.3274
# Epoch 133/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0553 - val_loss: 0.1552
# Epoch 134/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0725 - val_loss: 0.1208
# Epoch 135/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0706 - val_loss: 0.1034
# Epoch 136/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.1134 - val_loss: 0.1312
# Epoch 137/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0580 - val_loss: 0.1081
# Epoch 138/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0842 - val_loss: 0.4612
# Epoch 139/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0565 - val_loss: 0.0762
# Epoch 140/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0445 - val_loss: 0.1607
# Epoch 141/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - loss: 0.0429 - val_loss: 0.0571
# Epoch 142/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.0405 - val_loss: 0.1588
# Epoch 143/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0396 - val_loss: 0.0506
# Epoch 144/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0381 - val_loss: 0.1244
# Epoch 145/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0381 - val_loss: 0.0568
# Epoch 146/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0369 - val_loss: 0.1313
# Epoch 147/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0374 - val_loss: 0.0485
# Epoch 148/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0368 - val_loss: 0.1322
# Epoch 149/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0364 - val_loss: 0.0469
# Epoch 150/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - loss: 0.0346 - val_loss: 0.1400
# Epoch 151/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0361 - val_loss: 0.0536
# Epoch 152/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0344 - val_loss: 0.1350
# Epoch 153/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0344 - val_loss: 0.0454
# Epoch 154/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0339 - val_loss: 0.1109
# Epoch 155/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0338 - val_loss: 0.0525
# Epoch 156/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0342 - val_loss: 0.0997
# Epoch 157/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0345 - val_loss: 0.0476
# Epoch 158/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0363 - val_loss: 0.0996
# Epoch 159/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0346 - val_loss: 0.0444
# Epoch 160/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0362 - val_loss: 0.1239
# Epoch 161/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0348 - val_loss: 0.0421
# Epoch 162/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 0.0344 - val_loss: 0.1419
# Epoch 163/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0332 - val_loss: 0.0417
# Epoch 164/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0340 - val_loss: 0.1347
# Epoch 165/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0341 - val_loss: 0.0465
# Epoch 166/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0353 - val_loss: 0.1338
# Epoch 167/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0332 - val_loss: 0.0422
# Epoch 168/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0336 - val_loss: 0.1182
# Epoch 169/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - loss: 0.0320 - val_loss: 0.0474
# Epoch 170/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - loss: 0.0351 - val_loss: 0.1395
# Epoch 171/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0346 - val_loss: 0.0404
# Epoch 172/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0349 - val_loss: 0.1114
# Epoch 173/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0329 - val_loss: 0.0390
# Epoch 174/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0341 - val_loss: 0.1213
# Epoch 175/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0322 - val_loss: 0.0395
# Epoch 176/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0324 - val_loss: 0.1145
# Epoch 177/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0320 - val_loss: 0.0417
# Epoch 178/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0323 - val_loss: 0.1196
# Epoch 179/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0315 - val_loss: 0.0456
# Epoch 180/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 0.0358 - val_loss: 0.0979
# Epoch 181/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0316 - val_loss: 0.0422
# Epoch 182/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0323 - val_loss: 0.0847
# Epoch 183/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0290 - val_loss: 0.0394
# Epoch 184/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0306 - val_loss: 0.0666
# Epoch 185/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0295 - val_loss: 0.0452
# Epoch 186/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0313 - val_loss: 0.0658
# Epoch 187/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0297 - val_loss: 0.0389
# Epoch 188/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0333 - val_loss: 0.0526
# Epoch 189/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0296 - val_loss: 0.0407
# Epoch 190/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 0.0333 - val_loss: 0.0610
# Epoch 191/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0330 - val_loss: 0.0436
# Epoch 192/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0387 - val_loss: 0.0916
# Epoch 193/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0378 - val_loss: 0.0532
# Epoch 194/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0559 - val_loss: 0.1851
# Epoch 195/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0401 - val_loss: 0.0495
# Epoch 196/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0481 - val_loss: 0.2742
# Epoch 197/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0391 - val_loss: 0.0600
# Epoch 198/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0428 - val_loss: 0.1962
# Epoch 199/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 0.0392 - val_loss: 0.0595
# Epoch 200/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.0536 - val_loss: 0.1775
# Epoch 201/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0412 - val_loss: 0.0502
# Epoch 202/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0426 - val_loss: 0.1001
# Epoch 203/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0323 - val_loss: 0.0475
# Epoch 204/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0310 - val_loss: 0.1114
# Epoch 205/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0302 - val_loss: 0.0387
# Epoch 206/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0299 - val_loss: 0.1022
# Epoch 207/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0296 - val_loss: 0.0342
# Epoch 208/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0287 - val_loss: 0.0750
# Epoch 209/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0303 - val_loss: 0.0404
# Epoch 210/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 0.0361 - val_loss: 0.1698
# Epoch 211/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0345 - val_loss: 0.0454
# Epoch 212/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0388 - val_loss: 0.2090
# Epoch 213/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0319 - val_loss: 0.0405
# Epoch 214/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0316 - val_loss: 0.1470
# Epoch 215/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0308 - val_loss: 0.0422
# Epoch 216/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0292 - val_loss: 0.1136
# Epoch 217/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0290 - val_loss: 0.0374
# Epoch 218/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.0290 - val_loss: 0.1107
# Epoch 219/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0292 - val_loss: 0.0409
# Epoch 220/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0285 - val_loss: 0.1002
# Epoch 221/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0282 - val_loss: 0.0387
# Epoch 222/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0305 - val_loss: 0.1215
# Epoch 223/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0316 - val_loss: 0.0428
# Epoch 224/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0375 - val_loss: 0.1273
# Epoch 225/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0320 - val_loss: 0.0416
# Epoch 226/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0363 - val_loss: 0.1556
# Epoch 227/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0311 - val_loss: 0.0376
# Epoch 228/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 0.0315 - val_loss: 0.1576
# Epoch 229/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0288 - val_loss: 0.0403
# Epoch 230/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0272 - val_loss: 0.1122
# Epoch 231/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0288 - val_loss: 0.0417
# Epoch 232/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0303 - val_loss: 0.1476
# Epoch 233/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0302 - val_loss: 0.0399
# Epoch 234/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0326 - val_loss: 0.1184
# Epoch 235/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0291 - val_loss: 0.0395
# Epoch 236/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0306 - val_loss: 0.1147
# Epoch 237/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0282 - val_loss: 0.0415
# Epoch 237: early stopping
# Restoring model weights from the end of the best epoch: 207.
# 検証データの損失が最も小さかったエポック: 207
# エポック 207での学習損失: 0.03396543860435486
# エポック 207での検証損失: 0.03418852388858795

# %%
# 損失関数の推移
plt.plot(lstm_model.history.history['loss'], label='学習損失')
plt.plot(lstm_model.history.history['val_loss'], label='検証損失')
plt.title('損失の推移')
plt.xlabel('エポック')
plt.ylabel('損失')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# 検証データ（X_valid_scaled）は (samples, timesteps, features) の形
X_valid_copy = X_valid_scaled.copy()
baseline_preds = lstm_model.predict(X_valid_scaled).ravel()
baseline_score = mean_squared_error(y_valid_scaled.ravel(), baseline_preds)

# 特徴量数
n_features = X_valid_scaled.shape[2]
feature_names = engineered_df.columns

# 順列重要度を格納
importances = []

# 各特徴量について
for i in range(n_features):
    # コピーを作成
    X_permuted = X_valid_copy.copy()

    # 各time stepでその特徴をシャッフル
    for t in range(X_valid_scaled.shape[1]):  # timesteps
        np.random.seed(42)
        np.random.shuffle(X_permuted[:, t, i])

    # 予測してスコア計算
    permuted_preds = lstm_model.predict(X_permuted).ravel()
    permuted_score = mean_squared_error(y_valid_scaled.ravel(), permuted_preds)

    # スコアの悪化分を重要度とする
    importance = permuted_score - baseline_score
    importances.append(importance)

# 結果をDataFrameにまとめて可視化
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.xlabel('Permutation Importance (MSE Increase)')
plt.title('Feature Importance for LSTM (Keras)')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# 表としても表示
print(importance_df)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#            Feature  Importance
# 2             high    0.003996
# 1             open    0.003600
# 5           return    0.003464
# 3              low    0.003447
# 0            close    0.003293
# 6    sin_dayofyear    0.000871
# 8   sin_dayofmonth    0.000500
# 4           volume    0.000361
# 10   sin_dayofweek    0.000005
# 9   cos_dayofmonth   -0.000035
# 11   cos_dayofweek   -0.000053
# 7    cos_dayofyear   -0.000630

# %%
from sklearn.metrics import mean_squared_error

y_test_pred_scaled = lstm_model.predict(X_test_scaled)
y_test_pred = scaler_y.inverse_transform(y_test_pred_scaled)
y_test_pred = y_test_pred.flatten()
y_test = y_test.flatten()

test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))

print(f"Test RMSE: {test_rmse}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Test RMSE: 7.49839605159416

# %%
plt.figure(figsize=(12,8))
plt.plot(test[sequence_length:].index, y_test, label='実測値')
plt.plot(test[sequence_length:].index, y_test_pred, label='予測値')
plt.title('終値の予測', fontsize=25)
plt.xlabel('日付', fontsize=20)
plt.ylabel('価格(円)', fontsize=20)
plt.legend(fontsize=20)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.plot(test.index, test['close'].values, label='Actual')
plt.plot(test[sequence_length:].index, y_test_pred, label='Predicted')
plt.title('Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()
