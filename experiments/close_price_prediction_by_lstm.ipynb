# %% [markdown]
# <a href="https://colab.research.google.com/github/kaisei3506/close_price_prediction/blob/main/close_price_prediction_by_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 準備

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install japanize_matplotlib
import japanize_matplotlib
# Out:
# Requirement already satisfied: japanize_matplotlib in /usr/local/lib/python3.11/dist-packages (1.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from japanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.17.0)

# %%
# 再現性の確保

import os
import random
import numpy as np
import tensorflow as tf

os.environ['PYTHONHASHSEED'] = '42'

random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

try:
    tf.config.experimental.enable_op_determinism()
    print("TensorFlow deterministic operations enabled.")
except AttributeError as e:
    print(f"Note: tf.config.experimental.enable_op_determinism() not available in this TF version. Using TF_DETERMINISTIC_OPS='1' might be necessary if supported. Error: {e}")
# Out:
# TensorFlow deterministic operations enabled.

# %% [markdown]
# # 2. データの確認・前処理

# %%
# データの読み込み

# マイドライブにCSVファイルをアップロードし、パスを変更してください
df = pd.read_csv('/content/drive/MyDrive/assignment-main(new)/Trainee/time-series-prediction/stock_price.csv')
df
# Out:
#              日付け     終値     始値     高値     安値      出来高   変化率 %
# 0     2024-08-01  156.3  159.3  159.4  156.1   79.15M  -2.56%
# 1     2024-07-31  160.4  158.2  160.7  158.1  173.91M   1.07%
# 2     2024-07-30  158.7  158.8  159.2  158.0  138.14M  -0.63%
# 3     2024-07-29  159.7  158.7  160.2  158.4  126.28M   1.14%
# 4     2024-07-26  157.9  159.3  159.6  157.9  155.08M  -0.13%
# ...          ...    ...    ...    ...    ...      ...     ...
# 9197  1987-02-18  191.2  186.3  191.2  186.3  795.09M   4.82%
# 9198  1987-02-17  182.4  176.5  184.3  175.5  881.51M   3.93%
# 9199  1987-02-16  175.5  166.7  175.5  165.7  360.51M   1.74%
# 9200  1987-02-13  172.5  176.5  176.5  172.5  422.38M  -5.43%
# 9201  1987-02-12  182.4  182.4  182.4  182.4    1.28B  16.25%
#
# [9202 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9202 entries, 0 to 9201
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   日付け     9202 non-null   object
#  1   終値      9202 non-null   float64
#  2   始値      9202 non-null   float64
#  3   高値      9202 non-null   float64
#  4   安値      9202 non-null   float64
#  5   出来高     9202 non-null   object
#  6   変化率 %   9202 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 503.4+ KB

# %%
df.describe()
# Out:
#                 終値           始値           高値           安値
# count  9202.000000  9202.000000  9202.000000  9202.000000
# mean     92.180961    92.256183    93.176451    91.330146
# std      50.452228    50.598215    51.049837    50.087405
# min      33.000000    33.000000    33.200000    32.200000
# 25%      52.000000    52.100000    52.800000    51.500000
# 50%      85.100000    85.100000    86.050000    84.200000
# 75%     110.800000   110.800000   111.900000   109.275000
# max     305.900000   309.800000   311.800000   303.900000

# %%
# データクリーニング

def parse_volume(s):
  if 'B' in s:
    return float(s.replace('B', '')) * 1e9
  elif 'M' in s:
    return float(s.replace('M', '')) * 1e6
  else:
    return float(s)

def clean(df):
  df_new = df.copy()
  df_new = df_new[::-1]
  df_new = df_new.rename(columns={'日付け': 'date', '終値': 'close', '始値': 'open', '高値': 'high', '安値': 'low', '出来高': 'volume', '変化率 %': 'return'})
  df_new['date'] = pd.to_datetime(df_new['date'])
  df_new = df_new.set_index('date')
  df_new['volume'] = df_new['volume'].apply(parse_volume)
  df_new['return'] = df_new['return'].str.replace('%', '').astype(float) / 100
  return df_new

cleaned_df = clean(df)
cleaned_df
# Out:
#             close   open   high    low        volume  return
# date
# 1987-02-12  182.4  182.4  182.4  182.4  1.280000e+09  0.1625
# 1987-02-13  172.5  176.5  176.5  172.5  4.223800e+08 -0.0543
# 1987-02-16  175.5  166.7  175.5  165.7  3.605100e+08  0.0174
# 1987-02-17  182.4  176.5  184.3  175.5  8.815100e+08  0.0393
# 1987-02-18  191.2  186.3  191.2  186.3  7.950900e+08  0.0482
# ...           ...    ...    ...    ...           ...     ...
# 2024-07-26  157.9  159.3  159.6  157.9  1.550800e+08 -0.0013
# 2024-07-29  159.7  158.7  160.2  158.4  1.262800e+08  0.0114
# 2024-07-30  158.7  158.8  159.2  158.0  1.381400e+08 -0.0063
# 2024-07-31  160.4  158.2  160.7  158.1  1.739100e+08  0.0107
# 2024-08-01  156.3  159.3  159.4  156.1  7.915000e+07 -0.0256
#
# [9202 rows x 6 columns]

# %%
cleaned_df.describe()
# Out:
#              close         open         high          low        volume  \
# count  9202.000000  9202.000000  9202.000000  9202.000000  9.202000e+03
# mean     92.180961    92.256183    93.176451    91.330146  1.726677e+08
# std      50.452228    50.598215    51.049837    50.087405  1.251280e+08
# min      33.000000    33.000000    33.200000    32.200000  9.340000e+06
# 25%      52.000000    52.100000    52.800000    51.500000  8.073000e+07
# 50%      85.100000    85.100000    86.050000    84.200000  1.540150e+08
# 75%     110.800000   110.800000   111.900000   109.275000  2.305225e+08
# max     305.900000   309.800000   311.800000   303.900000  1.280000e+09
#
#             return
# count  9202.000000
# mean      0.000175
# std       0.018767
# min      -0.147400
# 25%      -0.009400
# 50%       0.000000
# 75%       0.009000
# max       0.162500

# %% [markdown]
# # 3. EDA

# %%
# 終値の推移

plt.figure(figsize=(12, 8))
plt.plot(cleaned_df['close'], label='終値')
plt.plot(cleaned_df['open'], label='始値')
plt.plot(cleaned_df['high'], label='高値')
plt.plot(cleaned_df['low'], label='安値')
plt.title('価格の推移', fontsize=25)
plt.xlabel('日付け', fontsize=20)
plt.ylabel('価格', fontsize=20)
plt.legend(fontsize=18)
plt.grid()
plt.show()

# %% [markdown]
# *   年代によってトレンドが異なる
# *   2019年以降は上昇トレンド
# →2019年以降のデータをモデル構築に利用

# %%
# 出来高の推移
plt.figure(figsize=(12, 8))
plt.plot(cleaned_df['volume'], label='出来高')
plt.title('出来高の推移', fontsize=25)
plt.xlabel('日付け', fontsize=20)
plt.ylabel('出来高', fontsize=20)
plt.grid()
plt.show()

# %%
# 終値のリターンの推移
plt.figure(figsize=(12, 8))
plt.plot(cleaned_df['return'], label='リターン')
plt.title('終値リターンの推移', fontsize=25)
plt.xlabel('日付け', fontsize=20)
plt.ylabel('リターン', fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# # 4. 特徴量エンジニアリング

# %%
# 特徴量エンジニアリング

def engineer(df_old):

  df_new = df_old.copy()

  # 季節成分

  df_new['sin_dayofyear'] = np.sin(2 * np.pi * df_new.index.dayofyear / 365)
  df_new['cos_dayofyear'] = np.cos(2 * np.pi * df_new.index.dayofyear / 365)
  df_new['sin_dayofmonth'] = np.sin(2 * np.pi * df_new.index.day / 30)
  df_new['cos_dayofmonth'] = np.cos(2 * np.pi * df_new.index.day / 30)

  # 移動平均、相対力指数
  sma_list = [5, 10]
  for i in sma_list:
    df_new[f'sma_{i}'] = df_new['close'].rolling(window=i).mean()
    df_new[f'ema_{i}'] = df_new['close'].ewm(span=i, adjust=False).mean()

  # 標準偏差
  for i in sma_list:
    df_new[f'std_{i}'] = df_new['close'].rolling(window=i).std()

  # ADX
  epsilon = 1e-6
  df_new['+DM'] = df_new['high'] - df_new['high'].shift(1)
  df_new['-DM'] = df_new['low'].shift(1) - df_new['low']
  df_new['TR'] = np.maximum.reduce([
    df_new['high'] - df_new['low'],
    abs(df_new['high'] - df_new['close'].shift(1)),
    abs(df_new['low'] - df_new['close'].shift(1))
    ])
  df_new['+DI'] = df_new['+DM'].rolling(window=14).sum() / (df_new['TR'].rolling(window=14).sum() + epsilon) * 100
  df_new['-DI'] = df_new['-DM'].rolling(window=14).sum() / (df_new['TR'].rolling(window=14).sum() + epsilon) * 100
  df_new['DX'] = abs((df_new['+DI'] - df_new['-DI']) / (df_new['+DI'] + df_new['-DI'] + epsilon)) * 100
  df_new['ADX'] = df_new['DX'].rolling(window=14).mean()

  # ストキャスティクス
  df_new['%K'] = (df_new['close'] - df_new['low'].rolling(window=14).min()) / (df_new['high'].rolling(window=14).max() - df_new['low'].rolling(window=14).min()) * 100
  df_new['%D'] = df_new['%K'].rolling(window=3).mean()



  df_new = df_new.drop(['volume', '+DM', '-DM', 'TR', '+DI', '-DI', '%K'], axis=1)

  df_new = df_new.dropna()


  return df_new

engineered_df = engineer(cleaned_df)
engineered_df
# Out:
#             close   open   high    low  return  sin_dayofyear  cos_dayofyear  \
# date
# 1987-03-23  260.8  263.7  267.6  260.8  0.0038       0.987349       0.158559
# 1987-03-24  256.9  264.7  264.7  256.9 -0.0150       0.989932       0.141540
# 1987-03-25  254.9  255.9  256.9  252.9 -0.0078       0.992222       0.124479
# 1987-03-26  262.7  258.8  264.7  255.9  0.0306       0.994218       0.107381
# 1987-03-27  274.5  267.6  284.3  263.7  0.0449       0.995919       0.090252
# ...           ...    ...    ...    ...     ...            ...            ...
# 2024-07-26  157.9  159.3  159.6  157.9 -0.0013      -0.425000      -0.905193
# 2024-07-29  159.7  158.7  160.2  158.4  0.0114      -0.471160      -0.882048
# 2024-07-30  158.7  158.8  159.2  158.0 -0.0063      -0.486273      -0.873807
# 2024-07-31  160.4  158.2  160.7  158.1  0.0107      -0.501242      -0.865307
# 2024-08-01  156.3  159.3  159.4  156.1 -0.0256      -0.516062      -0.856551
#
#             sin_dayofmonth  cos_dayofmonth   sma_5       ema_5  sma_10  \
# date
# 1987-03-23   -9.945219e-01        0.104528  267.26  266.156249  274.22
# 1987-03-24   -9.510565e-01        0.309017  263.14  263.070832  272.26
# 1987-03-25   -8.660254e-01        0.500000  259.22  260.347222  269.71
# 1987-03-26   -7.431448e-01        0.669131  259.02  261.131481  267.55
# 1987-03-27   -5.877853e-01        0.809017  261.96  265.587654  266.57
# ...                    ...             ...     ...         ...     ...
# 2024-07-26   -7.431448e-01        0.669131  159.02  158.602261  159.05
# 2024-07-29   -2.079117e-01        0.978148  158.98  158.968174  159.15
# 2024-07-30   -1.133108e-15        1.000000  158.58  158.878783  159.30
# 2024-07-31    2.079117e-01        0.978148  158.96  159.385855  159.37
# 2024-08-01    2.079117e-01        0.978148  158.60  158.357237  158.92
#
#                 ema_10     std_5     std_10            DX           ADX  \
# date
# 1987-03-23  269.115180  8.175145   9.394656  2.450001e+02  5.781730e+08
# 1987-03-24  266.894238  6.799485  10.804855  1.420000e+03  5.781730e+08
# 1987-03-25  264.713468  3.425931  11.646597  7.321840e+02  5.781729e+08
# 1987-03-26  264.347383  3.114001  10.595623  1.858621e+03  5.781721e+08
# 1987-03-27  266.193313  7.658198   9.240857  1.609375e+02  5.781706e+08
# ...                ...       ...        ...           ...           ...
# 2024-07-26  158.512757  1.221475   1.202082  2.100004e+03  8.685501e+08
# 2024-07-29  158.728619  1.188276   1.211289  1.733334e+03  4.649221e+08
# 2024-07-30  158.723416  0.701427   1.020893  2.913044e+02  4.649221e+08
# 2024-07-31  159.028249  1.066771   1.073985  1.509434e+09  5.727386e+08
# 2024-08-01  158.532204  1.600000   1.322288  2.285714e+02  5.727384e+08
#
#                    %D
# date
# 1987-03-23  12.637943
# 1987-03-24  10.700425
# 1987-03-25   8.295781
# 1987-03-26  12.402657
# 1987-03-27  30.492167
# ...               ...
# 2024-07-26  59.848485
# 2024-07-29  63.839616
# 2024-07-30  60.809313
# 2024-07-31  67.178561
# 2024-08-01  43.165785
#
# [9175 rows x 18 columns]

# %% [markdown]
# # 5. 再EDA

# %%
# 直近のデータに限定
df_used = engineered_df['2019-01-01':]

# %%
# STL分解

from statsmodels.tsa.seasonal import seasonal_decompose

def stl_decomposition(df, col, period):
  result = seasonal_decompose(df[col], model='multiplicative', period=period)
  fig, ax = plt.subplots(4, 1, figsize=(15, 8), sharex=True)
  fig.suptitle('終値を{}日周期でSTL分解'.format(period), fontsize=25)
  result.observed.plot(ax=ax[0])
  ax[0].set_ylabel('観測値', fontsize=15)
  result.trend.plot(ax=ax[1])
  ax[1].set_ylabel('トレンド成分', fontsize=15)
  result.seasonal.plot(ax=ax[2])
  ax[2].set_ylabel('季節成分', fontsize=15)
  result.resid.plot(ax=ax[3])
  ax[3].set_ylabel('残差成分', fontsize=15)
  for a in ax:
    a.set_xlabel(' ')
    a.label_outer()
  plt.tight_layout(rect=[0, 0, 1, 1])

  plt.xlabel('日付', fontsize=20)
  plt.show()

  seasonal_strength = 1 - np.var(result.resid) / np.var(result.seasonal + result.resid)
  print('季節性成分の強さ:', seasonal_strength)

# 252日周期の終値のSTL分解
stl_decomposition(df_used, 'close', 252)
# Out:
# 季節性成分の強さ: 0.10854667264370677

# %% [markdown]
# *   上昇トレンド
# *   周期性・季節性は弱い

# %%
# 自己相関、偏自己相関

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, ax = plt.subplots(2, 1, figsize=(15, 8))
plot_acf(df_used['close'], lags=252, ax=ax[0])
ax[0].set_title('終値の自己相関', fontsize=20)
ax[0].set_xlabel('ラグ', fontsize=15)
ax[0].set_ylabel('相関', fontsize=15)
plot_pacf(df_used['close'], lags=252, ax=ax[1])
ax[1].set_title('終値の偏自己相関', fontsize=20)
ax[1].set_xlabel('ラグ', fontsize=15)
ax[1].set_ylabel('相関', fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# *   ACFがゆっくり減衰→非定常
# *   PACFがラグ1のみ1.0でラグ２以降はほぼ0

# %%
# 検証期間の終値の推移

plt.figure(figsize=(12, 8))
plt.plot(df_used['2023-01-01':'2023-07-31']['close'])
plt.title('検証用データの終値', fontsize=25)
plt.xlabel('日付け', fontsize=20)
plt.ylabel('終値', fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# *   2023年5月下旬頃から不安定 → 検証期間を限定

# %% [markdown]
# # 5. 学習用データの作成

# %%
# データの分割

train_valid = df_used['2019-01-01':'2023-12-31']

train = train_valid[:'2022-11-30']
enbargo_train_valid = train_valid['2022-12-01':'2022-12-31']
valid = train_valid['2023-01-01':'2023-05-15']
enbargo_valid_test = engineered_df['2023-05-16':'2023-12-31']
test = engineered_df['2024-01-01':'2024-07-31']

# %%
sequence_length = 22 # 入力シーケンス長
predict_length = 1 # 出力シーケンス長

# LSTM用のデータセットを作成

def create_dataset(data, sequence_length, predict_length):
  X, y = [], []
  for i in range(len(data) - sequence_length - predict_length + 1):
    X.append(data[i:i+sequence_length, :])
    y.append(data[i+sequence_length:i+sequence_length+predict_length, 0])
  return np.array(X), np.array(y)

X_train, y_train = create_dataset(train.values, sequence_length, predict_length)
X_valid, y_valid = create_dataset(valid.values, sequence_length, predict_length)
X_test, y_test = create_dataset(test.values, sequence_length, predict_length)

# LSTM用の入力形に変換（サンプル数、入力シーケンス長、特徴量数）

y_train = y_train.reshape(y_train.shape[0], y_train.shape[1], 1)
y_valid = y_valid.reshape(y_valid.shape[0], y_valid.shape[1], 1)

# %%
from sklearn.preprocessing import StandardScaler

# 特徴量（X）のスケーリング
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
X_valid_scaled = scaler_X.transform(X_valid.reshape(-1, X_valid.shape[-1])).reshape(X_valid.shape)
X_test_scaled = scaler_X.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# 目的変数（y）のスケーリング
scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, y_train.shape[-1])).reshape(y_train.shape)
y_valid_scaled = scaler_y.transform(y_valid.reshape(-1, y_valid.shape[-1])).reshape(y_valid.shape)
y_test_scaled = scaler_y.transform(y_test.reshape(-1, y_test.shape[-1])).reshape(y_test.shape)

# %% [markdown]
# # 6. 学習

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras import optimizers as optim
from tensorflow.keras import regularizers
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Layer
from tensorflow.keras.models import Model
from tensorflow.keras import layers, models, regularizers, optimizers

# %%
# LSTM

lstm_model = Sequential()

lstm_model.add(LSTM(units=128,
                    return_sequences=True,
                    input_shape=(X_train.shape[1], X_train.shape[2]),
                    kernel_regularizer=regularizers.l2(0.001),
                    recurrent_regularizer=regularizers.l2(0.001)
                    )
)

lstm_model.add(Dropout(0.2))

lstm_model.add(LSTM(units=64,
                    return_sequences=True,
                    kernel_regularizer=regularizers.l2(0.001),
                    recurrent_regularizer=regularizers.l2(0.001)
                    )
)

lstm_model.add(Dropout(0.2))

lstm_model.add(LSTM(units=32,
                    return_sequences=False,
                    kernel_regularizer=regularizers.l2(0.001),
                    recurrent_regularizer=regularizers.l2(0.001)
                    )
)

lstm_model.add(Dropout(0.2))

lstm_model.add(Dense(predict_length,
                     kernel_regularizer=regularizers.l2(0.001)
                     )
)


optimizer = optim.Adam(learning_rate=0.001)
lstm_model.compile(optimizer=optimizer, loss='mse')
lstm_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 22, 128)        │        75,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 22, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 22, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 22, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 137,121 (535.63 KB)
#  Trainable params: 137,121 (535.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Transformer


# ポジショナルエンコーディング層
class PositionalEncoding(layers.Layer):
  def __init__(self, sequence_len, d_model):
      super(PositionalEncoding, self).__init__()
      self.pos_encoding = self.positional_encoding(sequence_len, d_model)

  def get_config(self):
      return {"sequence_len": self.pos_encoding.shape[1], "d_model": self.pos_encoding.shape[2]}

  def get_angles(self, pos, i, d_model):
      angles = pos / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
      return angles

  def positional_encoding(self, position, d_model):
      angle_rads = self.get_angles(
          pos=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
          i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
          d_model=d_model)

      sines = tf.math.sin(angle_rads[:, 0::2])
      cosines = tf.math.cos(angle_rads[:, 1::2])
      pos_encoding = tf.concat([sines, cosines], axis=-1)
      return pos_encoding[tf.newaxis, ...]

  def call(self, inputs):
      return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# エンコーダ
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.2):
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size,
                                   kernel_regularizer=regularizers.l2(0.001))(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Dense(ff_dim, activation="relu",
                     kernel_regularizer=regularizers.l2(0.001))(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(inputs.shape[-1],
                     kernel_regularizer=regularizers.l2(0.001))(x)
    return x + res

# モデル構築
sequence_length = X_train.shape[1]
num_features = X_train.shape[2]

inputs = layers.Input(shape=(sequence_length, num_features))

# 1. ポジショナルエンコーディング
x = PositionalEncoding(sequence_length, num_features)(inputs)

# 2. エンコーダ
x = transformer_encoder(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.2)
x = transformer_encoder(x, head_size=64, num_heads=4, ff_dim=128, dropout=0.2)

# 3. グローバル平均プーリング
x = layers.GlobalAveragePooling1D()(x)

# 4. 出力層
outputs = layers.Dense(predict_length,
                       kernel_regularizer=regularizers.l2(0.001))(x)

# モデル定義
transformer_model = models.Model(inputs, outputs)
transformer_model.compile(
    loss="mse",
    optimizer=optimizers.Adam(learning_rate=0.001),
)

transformer_model.summary()
# Out:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 22, 18)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encoding │ (None, 22, 18)    │          0 │ input_layer_3[0]… │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 22, 18)    │         36 │ positional_encod… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 22, 18)    │     19,218 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 22, 18)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 22, 18)    │          0 │ dropout_10[0][0], │
# │                     │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 22, 18)    │         36 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 22, 128)   │      2,432 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 22, 128)   │          0 │ dense_3[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 22, 18)    │      2,322 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 22, 18)    │          0 │ dense_4[0][0],    │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 22, 18)    │         36 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 22, 18)    │     19,218 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 22, 18)    │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 22, 18)    │          0 │ dropout_13[0][0], │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 22, 18)    │         36 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 22, 128)   │      2,432 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 22, 128)   │          0 │ dense_5[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 22, 18)    │      2,322 │ dropout_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 22, 18)    │          0 │ dense_6[0][0],    │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 18)        │          0 │ add_3[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1)         │         19 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 48,107 (187.92 KB)
#  Trainable params: 48,107 (187.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# モデルを学習させる関数

def train_model_with_early_stopping(model,
                                    X_train, y_train,
                                    X_valid, y_valid,
                                    epochs=1000,
                                    batch_size=128,
                                    patience=20):

  # 早期終了
  es = EarlyStopping(monitor='val_loss',
                      mode='min',
                      verbose=1,
                      patience=patience,
                      restore_best_weights=True)

  # 学習
  history = model.fit(
      X_train, y_train,
      epochs=epochs,
      batch_size=batch_size,
      validation_data=(X_valid, y_valid),
      shuffle=False,
      callbacks=[es]
  )

  # 検証スコアが最も良いエポック、訓練・検証データの損失を保存
  best_epoch = np.argmin(history.history['val_loss']) + 1
  best_train_loss = history.history['loss'][best_epoch - 1]
  best_val_loss = history.history['val_loss'][best_epoch - 1]

  print(f"\n最良エポック: {best_epoch}")
  print(f"訓練損失: {best_train_loss}")
  print(f"検証損失: {best_val_loss}")

  # 学習曲線の描画
  plt.figure(figsize=(10, 5))
  plt.plot(history.history['loss'], label='Train Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.axvline(x=best_epoch - 1, color='r', linestyle='--', label='Best Epoch')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.title('Training Curve')
  plt.grid()
  plt.tight_layout()
  plt.show()

  return model

# %%
# LSTMモデルの学習
lstm_model = train_model_with_early_stopping(lstm_model,
                                             X_train_scaled, y_train_scaled,
                                             X_valid_scaled, y_valid_scaled
)
# Out:
# Epoch 1/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 15s 753ms/step - loss: 0.7411 - val_loss: 0.6562
# Epoch 2/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - loss: 0.6703 - val_loss: 0.5260
# Epoch 3/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.6103 - val_loss: 0.5227
# Epoch 4/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.5507 - val_loss: 0.4762
# Epoch 5/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.4920 - val_loss: 0.7861
# Epoch 6/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.4635 - val_loss: 0.5461
# Epoch 7/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.4484 - val_loss: 0.4582
# Epoch 8/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.4347 - val_loss: 0.4520
# Epoch 9/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - loss: 0.4165 - val_loss: 0.4719
# Epoch 10/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - loss: 0.4034 - val_loss: 0.4543
# Epoch 11/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.3868 - val_loss: 0.4286
# Epoch 12/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - loss: 0.3728 - val_loss: 0.4188
# Epoch 13/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - loss: 0.3615 - val_loss: 0.4078
# Epoch 14/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.3489 - val_loss: 0.3956
# Epoch 15/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.3374 - val_loss: 0.3942
# Epoch 16/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 303ms/step - loss: 0.3275 - val_loss: 0.3671
# Epoch 17/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 283ms/step - loss: 0.3138 - val_loss: 0.3616
# Epoch 18/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 226ms/step - loss: 0.3090 - val_loss: 0.3357
# Epoch 19/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - loss: 0.3026 - val_loss: 0.3734
# Epoch 20/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - loss: 0.3072 - val_loss: 0.2840
# Epoch 21/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - loss: 0.2854 - val_loss: 0.4078
# Epoch 22/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - loss: 0.2779 - val_loss: 0.3040
# Epoch 23/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 444ms/step - loss: 0.2731 - val_loss: 0.3105
# Epoch 24/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 306ms/step - loss: 0.2632 - val_loss: 0.3135
# Epoch 25/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - loss: 0.2529 - val_loss: 0.3062
# Epoch 26/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 222ms/step - loss: 0.2475 - val_loss: 0.3115
# Epoch 27/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 280ms/step - loss: 0.2410 - val_loss: 0.2844
# Epoch 28/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 388ms/step - loss: 0.2344 - val_loss: 0.2862
# Epoch 29/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - loss: 0.2297 - val_loss: 0.2734
# Epoch 30/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - loss: 0.2224 - val_loss: 0.2768
# Epoch 31/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - loss: 0.2195 - val_loss: 0.2829
# Epoch 32/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.2170 - val_loss: 0.2370
# Epoch 33/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.2119 - val_loss: 0.3150
# Epoch 34/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.2105 - val_loss: 0.2227
# Epoch 35/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - loss: 0.2037 - val_loss: 0.2746
# Epoch 36/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 0.1965 - val_loss: 0.2253
# Epoch 37/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.1918 - val_loss: 0.2525
# Epoch 38/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - loss: 0.1884 - val_loss: 0.2193
# Epoch 39/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.1846 - val_loss: 0.2294
# Epoch 40/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step - loss: 0.1814 - val_loss: 0.2282
# Epoch 41/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.1782 - val_loss: 0.2289
# Epoch 42/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - loss: 0.1752 - val_loss: 0.1981
# Epoch 43/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 193ms/step - loss: 0.1734 - val_loss: 0.2287
# Epoch 44/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - loss: 0.1683 - val_loss: 0.2105
# Epoch 45/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - loss: 0.1656 - val_loss: 0.2039
# Epoch 46/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.1630 - val_loss: 0.1983
# Epoch 47/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - loss: 0.1613 - val_loss: 0.2003
# Epoch 48/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - loss: 0.1568 - val_loss: 0.2009
# Epoch 49/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 341ms/step - loss: 0.1654 - val_loss: 0.2111
# Epoch 50/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 294ms/step - loss: 0.1924 - val_loss: 0.3763
# Epoch 51/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - loss: 0.1896 - val_loss: 0.1669
# Epoch 52/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - loss: 0.1735 - val_loss: 0.2466
# Epoch 53/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.1558 - val_loss: 0.1701
# Epoch 54/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 0.1527 - val_loss: 0.2569
# Epoch 55/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - loss: 0.1452 - val_loss: 0.1669
# Epoch 56/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.1398 - val_loss: 0.2078
# Epoch 57/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - loss: 0.1385 - val_loss: 0.1784
# Epoch 58/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 330ms/step - loss: 0.1348 - val_loss: 0.1938
# Epoch 59/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - loss: 0.1342 - val_loss: 0.1707
# Epoch 60/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - loss: 0.1325 - val_loss: 0.1878
# Epoch 61/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - loss: 0.1309 - val_loss: 0.1594
# Epoch 62/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 0.1269 - val_loss: 0.1894
# Epoch 63/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.1248 - val_loss: 0.1526
# Epoch 64/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.1236 - val_loss: 0.1790
# Epoch 65/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - loss: 0.1214 - val_loss: 0.1644
# Epoch 66/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - loss: 0.1192 - val_loss: 0.1769
# Epoch 67/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - loss: 0.1198 - val_loss: 0.1473
# Epoch 68/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - loss: 0.1161 - val_loss: 0.1735
# Epoch 69/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - loss: 0.1158 - val_loss: 0.1537
# Epoch 70/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - loss: 0.1159 - val_loss: 0.1759
# Epoch 71/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - loss: 0.1210 - val_loss: 0.1516
# Epoch 72/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 353ms/step - loss: 0.1327 - val_loss: 0.3107
# Epoch 73/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - loss: 0.1278 - val_loss: 0.1221
# Epoch 74/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.1136 - val_loss: 0.1857
# Epoch 75/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 0.1126 - val_loss: 0.1460
# Epoch 76/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1094 - val_loss: 0.1879
# Epoch 77/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.1076 - val_loss: 0.1340
# Epoch 78/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - loss: 0.1068 - val_loss: 0.1984
# Epoch 79/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.1034 - val_loss: 0.1269
# Epoch 80/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - loss: 0.1010 - val_loss: 0.1636
# Epoch 81/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step - loss: 0.1015 - val_loss: 0.1403
# Epoch 82/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 283ms/step - loss: 0.1009 - val_loss: 0.1932
# Epoch 83/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.1002 - val_loss: 0.1229
# Epoch 84/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - loss: 0.0959 - val_loss: 0.1460
# Epoch 85/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - loss: 0.0943 - val_loss: 0.1450
# Epoch 86/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - loss: 0.0934 - val_loss: 0.1521
# Epoch 87/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - loss: 0.0938 - val_loss: 0.1161
# Epoch 88/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - loss: 0.0924 - val_loss: 0.1448
# Epoch 89/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - loss: 0.0906 - val_loss: 0.1286
# Epoch 90/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0903 - val_loss: 0.1369
# Epoch 91/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - loss: 0.0880 - val_loss: 0.1197
# Epoch 92/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - loss: 0.0897 - val_loss: 0.1164
# Epoch 93/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - loss: 0.0918 - val_loss: 0.1544
# Epoch 94/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - loss: 0.0982 - val_loss: 0.1235
# Epoch 95/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - loss: 0.1073 - val_loss: 0.1960
# Epoch 96/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 276ms/step - loss: 0.0978 - val_loss: 0.1076
# Epoch 97/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 246ms/step - loss: 0.0951 - val_loss: 0.1842
# Epoch 98/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 189ms/step - loss: 0.0894 - val_loss: 0.0982
# Epoch 99/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - loss: 0.0848 - val_loss: 0.1677
# Epoch 100/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - loss: 0.0875 - val_loss: 0.1000
# Epoch 101/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 281ms/step - loss: 0.0853 - val_loss: 0.2083
# Epoch 102/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 329ms/step - loss: 0.0815 - val_loss: 0.0962
# Epoch 103/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - loss: 0.0799 - val_loss: 0.1469
# Epoch 104/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 279ms/step - loss: 0.0824 - val_loss: 0.1035
# Epoch 105/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 326ms/step - loss: 0.0775 - val_loss: 0.1289
# Epoch 106/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 414ms/step - loss: 0.0778 - val_loss: 0.1169
# Epoch 107/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - loss: 0.0767 - val_loss: 0.1340
# Epoch 108/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step - loss: 0.0760 - val_loss: 0.1229
# Epoch 109/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - loss: 0.0755 - val_loss: 0.1048
# Epoch 110/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - loss: 0.0759 - val_loss: 0.1132
# Epoch 111/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 392ms/step - loss: 0.0728 - val_loss: 0.1171
# Epoch 112/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - loss: 0.0736 - val_loss: 0.1116
# Epoch 113/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 345ms/step - loss: 0.0725 - val_loss: 0.1301
# Epoch 114/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - loss: 0.0766 - val_loss: 0.1102
# Epoch 115/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - loss: 0.0817 - val_loss: 0.1420
# Epoch 116/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - loss: 0.0853 - val_loss: 0.0974
# Epoch 117/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - loss: 0.0924 - val_loss: 0.1861
# Epoch 118/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0810 - val_loss: 0.0865
# Epoch 119/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0745 - val_loss: 0.2173
# Epoch 120/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0755 - val_loss: 0.0884
# Epoch 121/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0718 - val_loss: 0.1968
# Epoch 122/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0701 - val_loss: 0.0940
# Epoch 123/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0696 - val_loss: 0.1312
# Epoch 124/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0723 - val_loss: 0.1029
# Epoch 125/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0665 - val_loss: 0.1205
# Epoch 126/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - loss: 0.0653 - val_loss: 0.1138
# Epoch 127/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - loss: 0.0642 - val_loss: 0.1116
# Epoch 128/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.0629 - val_loss: 0.1264
# Epoch 129/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0626 - val_loss: 0.0981
# Epoch 130/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0618 - val_loss: 0.1181
# Epoch 131/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0633 - val_loss: 0.0917
# Epoch 132/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0625 - val_loss: 0.1293
# Epoch 133/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0639 - val_loss: 0.0838
# Epoch 134/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0649 - val_loss: 0.1386
# Epoch 135/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0631 - val_loss: 0.1055
# Epoch 136/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0626 - val_loss: 0.1322
# Epoch 137/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0626 - val_loss: 0.0834
# Epoch 138/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - loss: 0.0636 - val_loss: 0.1383
# Epoch 139/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - loss: 0.0600 - val_loss: 0.0989
# Epoch 140/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 117ms/step - loss: 0.0603 - val_loss: 0.1220
# Epoch 141/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0624 - val_loss: 0.0743
# Epoch 142/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0624 - val_loss: 0.1380
# Epoch 143/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0594 - val_loss: 0.0885
# Epoch 144/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0579 - val_loss: 0.1196
# Epoch 145/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0562 - val_loss: 0.0924
# Epoch 146/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0559 - val_loss: 0.1040
# Epoch 147/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0557 - val_loss: 0.0886
# Epoch 148/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - loss: 0.0569 - val_loss: 0.1175
# Epoch 149/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - loss: 0.0566 - val_loss: 0.0873
# Epoch 150/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0559 - val_loss: 0.1062
# Epoch 151/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0579 - val_loss: 0.0813
# Epoch 152/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 0.0615 - val_loss: 0.1416
# Epoch 153/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 194ms/step - loss: 0.0631 - val_loss: 0.0783
# Epoch 154/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 0.0675 - val_loss: 0.1446
# Epoch 155/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.0584 - val_loss: 0.0806
# Epoch 156/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0544 - val_loss: 0.1105
# Epoch 157/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - loss: 0.0520 - val_loss: 0.0824
# Epoch 158/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 0.0523 - val_loss: 0.1106
# Epoch 159/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - loss: 0.0526 - val_loss: 0.0836
# Epoch 160/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0540 - val_loss: 0.1242
# Epoch 161/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0559 - val_loss: 0.0703
# Epoch 162/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0587 - val_loss: 0.1810
# Epoch 163/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0588 - val_loss: 0.0643
# Epoch 164/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0524 - val_loss: 0.1364
# Epoch 165/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0514 - val_loss: 0.0699
# Epoch 166/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - loss: 0.0506 - val_loss: 0.1118
# Epoch 167/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - loss: 0.0498 - val_loss: 0.0873
# Epoch 168/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.0503 - val_loss: 0.0957
# Epoch 169/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0499 - val_loss: 0.0771
# Epoch 170/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0481 - val_loss: 0.1144
# Epoch 171/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0491 - val_loss: 0.0739
# Epoch 172/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0478 - val_loss: 0.0959
# Epoch 173/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.0464 - val_loss: 0.0908
# Epoch 174/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0484 - val_loss: 0.1064
# Epoch 175/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0496 - val_loss: 0.0801
# Epoch 176/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0485 - val_loss: 0.0747
# Epoch 177/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - loss: 0.0451 - val_loss: 0.0956
# Epoch 178/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - loss: 0.0483 - val_loss: 0.0772
# Epoch 179/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 0.0515 - val_loss: 0.1134
# Epoch 180/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0557 - val_loss: 0.0638
# Epoch 181/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - loss: 0.0646 - val_loss: 0.1002
# Epoch 182/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - loss: 0.0487 - val_loss: 0.0676
# Epoch 183/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.0448 - val_loss: 0.0826
# Epoch 184/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 0.0455 - val_loss: 0.0799
# Epoch 185/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 283ms/step - loss: 0.0496 - val_loss: 0.0711
# Epoch 186/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 360ms/step - loss: 0.0537 - val_loss: 0.0799
# Epoch 187/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - loss: 0.0520 - val_loss: 0.0762
# Epoch 188/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - loss: 0.0564 - val_loss: 0.0959
# Epoch 189/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - loss: 0.0571 - val_loss: 0.0721
# Epoch 190/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - loss: 0.0729 - val_loss: 0.1909
# Epoch 191/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - loss: 0.0579 - val_loss: 0.0571
# Epoch 192/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 274ms/step - loss: 0.0505 - val_loss: 0.1631
# Epoch 193/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - loss: 0.0469 - val_loss: 0.0596
# Epoch 194/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 0.0491 - val_loss: 0.1112
# Epoch 195/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.0522 - val_loss: 0.0582
# Epoch 196/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.0442 - val_loss: 0.0936
# Epoch 197/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - loss: 0.0427 - val_loss: 0.0744
# Epoch 198/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 0.0434 - val_loss: 0.0897
# Epoch 199/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 228ms/step - loss: 0.0417 - val_loss: 0.1010
# Epoch 200/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step - loss: 0.0420 - val_loss: 0.0768
# Epoch 201/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0403 - val_loss: 0.0844
# Epoch 202/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 154ms/step - loss: 0.0419 - val_loss: 0.0757
# Epoch 203/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0411 - val_loss: 0.0924
# Epoch 204/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.0403 - val_loss: 0.0685
# Epoch 205/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.0390 - val_loss: 0.0818
# Epoch 206/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - loss: 0.0396 - val_loss: 0.0736
# Epoch 207/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 224ms/step - loss: 0.0396 - val_loss: 0.0710
# Epoch 208/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 432ms/step - loss: 0.0407 - val_loss: 0.0684
# Epoch 209/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - loss: 0.0456 - val_loss: 0.1238
# Epoch 210/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 0.0531 - val_loss: 0.0719
# Epoch 211/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - loss: 0.0645 - val_loss: 0.1481
# Epoch 211: early stopping
# Restoring model weights from the end of the best epoch: 191.
#
# 最良エポック: 191
# 訓練損失: 0.07142694294452667
# 検証損失: 0.05714055523276329

# %%
# Transformerモデルの学習
transformer_model = train_model_with_early_stopping(transformer_model,
                                                     X_train_scaled, y_train_scaled,
                                                     X_valid_scaled, y_valid_scaled
)
# Out:
# Epoch 1/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - loss: 0.9242 - val_loss: 1.5413
# Epoch 2/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 0.5658 - val_loss: 0.5945
# Epoch 3/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - loss: 0.8036 - val_loss: 1.7914
# Epoch 4/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.8323 - val_loss: 1.4477
# Epoch 5/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.6721 - val_loss: 0.7916
# Epoch 6/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.2994 - val_loss: 0.2802
# Epoch 7/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - loss: 0.3120 - val_loss: 0.2471
# Epoch 8/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - loss: 0.2642 - val_loss: 0.3619
# Epoch 9/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - loss: 0.2539 - val_loss: 0.3698
# Epoch 10/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - loss: 0.2517 - val_loss: 0.2861
# Epoch 11/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.2474 - val_loss: 0.2598
# Epoch 12/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.2449 - val_loss: 0.2658
# Epoch 13/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.2396 - val_loss: 0.2925
# Epoch 14/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - loss: 0.2382 - val_loss: 0.2720
# Epoch 15/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.2347 - val_loss: 0.2526
# Epoch 16/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - loss: 0.2357 - val_loss: 0.2506
# Epoch 17/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - loss: 0.2315 - val_loss: 0.2604
# Epoch 18/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - loss: 0.2292 - val_loss: 0.2479
# Epoch 19/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.2283 - val_loss: 0.2335
# Epoch 20/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.2274 - val_loss: 0.2379
# Epoch 21/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.2243 - val_loss: 0.2413
# Epoch 22/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.2237 - val_loss: 0.2315
# Epoch 23/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - loss: 0.2207 - val_loss: 0.2274
# Epoch 24/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 0.2200 - val_loss: 0.2289
# Epoch 25/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - loss: 0.2192 - val_loss: 0.2267
# Epoch 26/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 220ms/step - loss: 0.2183 - val_loss: 0.2277
# Epoch 27/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - loss: 0.2188 - val_loss: 0.2228
# Epoch 28/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.2176 - val_loss: 0.2290
# Epoch 29/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 0.2159 - val_loss: 0.2151
# Epoch 30/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.2177 - val_loss: 0.2216
# Epoch 31/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 322ms/step - loss: 0.2154 - val_loss: 0.2213
# Epoch 32/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 317ms/step - loss: 0.2135 - val_loss: 0.2152
# Epoch 33/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 405ms/step - loss: 0.2124 - val_loss: 0.2220
# Epoch 34/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.2131 - val_loss: 0.2080
# Epoch 35/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - loss: 0.2174 - val_loss: 0.2248
# Epoch 36/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step - loss: 0.2353 - val_loss: 0.2018
# Epoch 37/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 278ms/step - loss: 0.2709 - val_loss: 0.2217
# Epoch 38/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 316ms/step - loss: 0.2958 - val_loss: 0.2253
# Epoch 39/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - loss: 0.2744 - val_loss: 0.1971
# Epoch 40/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - loss: 0.2601 - val_loss: 0.3176
# Epoch 41/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.2253 - val_loss: 0.1970
# Epoch 42/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 0.2283 - val_loss: 0.2962
# Epoch 43/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - loss: 0.2525 - val_loss: 0.2095
# Epoch 44/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 335ms/step - loss: 0.2442 - val_loss: 0.2061
# Epoch 45/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - loss: 0.2438 - val_loss: 0.2533
# Epoch 46/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.2167 - val_loss: 0.1936
# Epoch 47/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.2111 - val_loss: 0.2408
# Epoch 48/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 267ms/step - loss: 0.2046 - val_loss: 0.1943
# Epoch 49/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - loss: 0.2015 - val_loss: 0.2197
# Epoch 50/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - loss: 0.1998 - val_loss: 0.2019
# Epoch 51/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step - loss: 0.2017 - val_loss: 0.2146
# Epoch 52/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - loss: 0.1987 - val_loss: 0.2033
# Epoch 53/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - loss: 0.1991 - val_loss: 0.1991
# Epoch 54/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1994 - val_loss: 0.2034
# Epoch 55/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - loss: 0.1975 - val_loss: 0.1974
# Epoch 56/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1974 - val_loss: 0.2059
# Epoch 57/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.1962 - val_loss: 0.1952
# Epoch 58/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.1951 - val_loss: 0.2048
# Epoch 59/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1954 - val_loss: 0.1970
# Epoch 60/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - loss: 0.1939 - val_loss: 0.2060
# Epoch 61/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - loss: 0.1936 - val_loss: 0.1930
# Epoch 62/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - loss: 0.1927 - val_loss: 0.1997
# Epoch 63/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1941 - val_loss: 0.1960
# Epoch 64/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1997 - val_loss: 0.2011
# Epoch 65/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.2038 - val_loss: 0.1994
# Epoch 66/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 0.2128 - val_loss: 0.1926
# Epoch 67/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - loss: 0.2115 - val_loss: 0.2200
# Epoch 68/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - loss: 0.2009 - val_loss: 0.1835
# Epoch 69/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 253ms/step - loss: 0.2050 - val_loss: 0.2698
# Epoch 70/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - loss: 0.2494 - val_loss: 0.1802
# Epoch 71/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - loss: 0.3367 - val_loss: 0.2964
# Epoch 72/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - loss: 0.4644 - val_loss: 0.2738
# Epoch 73/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - loss: 0.2651 - val_loss: 0.1826
# Epoch 74/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: 0.2083 - val_loss: 0.2635
# Epoch 75/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: 0.1937 - val_loss: 0.2144
# Epoch 76/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.1893 - val_loss: 0.1935
# Epoch 77/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - loss: 0.1872 - val_loss: 0.2183
# Epoch 78/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 227ms/step - loss: 0.1869 - val_loss: 0.1967
# Epoch 79/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 0.1853 - val_loss: 0.2014
# Epoch 80/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - loss: 0.1835 - val_loss: 0.1973
# Epoch 81/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - loss: 0.1824 - val_loss: 0.2005
# Epoch 82/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 0.1820 - val_loss: 0.1978
# Epoch 83/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.1816 - val_loss: 0.1984
# Epoch 84/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.1813 - val_loss: 0.1954
# Epoch 85/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.1799 - val_loss: 0.1944
# Epoch 86/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - loss: 0.1800 - val_loss: 0.1971
# Epoch 87/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.1786 - val_loss: 0.1950
# Epoch 88/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 255ms/step - loss: 0.1784 - val_loss: 0.1917
# Epoch 89/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 199ms/step - loss: 0.1782 - val_loss: 0.1993
# Epoch 90/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1778 - val_loss: 0.1883
# Epoch 90: early stopping
# Restoring model weights from the end of the best epoch: 70.
#
# 最良エポック: 70
# 訓練損失: 0.2580139935016632
# 検証損失: 0.18019288778305054

# %% [markdown]
# # 7. モデルの評価

# %%
from sklearn.metrics import mean_squared_error

# テストデータに対する汎化性能を評価

def evaluate(model, X_test_scaled, y_test_scaled, y_test, scaler_y, test_df, sequence_length):
    y_test_pred_scaled = model.predict(X_test_scaled)
    y_test_pred = scaler_y.inverse_transform(y_test_pred_scaled)
    y_test_pred = y_test_pred.flatten()
    y_test = y_test.flatten()

    scaled_test_mse = mean_squared_error(y_test_scaled, y_test_pred_scaled)
    inversed_test_mse = mean_squared_error(y_test, y_test_pred)
    inversed_test_rmse = np.sqrt(inversed_test_mse)

    print(f"Scaled Test MSE: {scaled_test_mse}")
    print(f"Inversed Test MSE: {inversed_test_mse}")
    print(f"Inversed Test RMSE: {inversed_test_rmse}")

    plt.figure(figsize=(16, 8))
    plt.plot(test_df.index, test_df['close'].values, label='実測値')
    plt.plot(test_df[sequence_length:].index, y_test_pred, label='予測値')
    plt.title('終値の予測', fontsize=25)
    plt.xlabel('日付', fontsize=20)
    plt.ylabel('終値', fontsize=20)
    plt.legend(fontsize=20)
    plt.grid()
    plt.show()

# %%
# LSTMモデルの評価
evaluate(lstm_model, X_test_scaled, y_test_scaled, y_test, scaler_y, test, sequence_length)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step
# Scaled Test MSE: 0.37400223070894234
# Inversed Test MSE: 162.20390745473668
# Inversed Test RMSE: 12.735929783676443

# %%
# Transformerモデルの評価
evaluate(transformer_model, X_test_scaled, y_test_scaled, y_test, scaler_y, test, sequence_length)
# Out:
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# WARNING:tensorflow:5 out of the last 71 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e76760bade0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step
# Scaled Test MSE: 0.061490919121148346
# Inversed Test MSE: 26.66846557411473
# Inversed Test RMSE: 5.164151970470537
